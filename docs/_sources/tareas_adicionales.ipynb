# %% [markdown]
# # Tareas Adicionales

# %% [markdown]
# ## Acceso a los materiales
#
# 📚 **Google Classroom:** [Ingresar al aula](https://classroom.google.com/c/NjI3NTQ1ODc1OTgx?cjc=gdembh3)
# 🔑 **Código de acceso:** `gdembh3`
#
# ---

# %% [markdown]
# Ver los dos videos de **Taller Testimonio** disponibles en Google Classroom, evalúe cada uno de los testimonios con base en la lista de la página 34 manual de Padres Espirituales.
#
# > _(Escribe tu comentario aquí)_
#
# ---

# %% [markdown]
# <iframe src="https://docs.google.com/forms/d/e/1FAIpQLSeR5Kbgj_x0YoCpmT5FDL1uE7OUk60gzNYW_OR4j2PwEPLgGQ/viewform?embedded=true" width="640" height="934" frameborder="0" marginheight="0" marginwidth="0">Loading…</iframe>
