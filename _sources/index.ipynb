# %% [markdown]
#  # Padres Espirituales I — Mayo 2026
#
# Bienvenido, aquí encontrarás las tareas, talleres y quices organizados por clase.
#
# ---
#
# ## Contenido del curso
#
# | Clase | Tema principal |
# |-------|---------------|
# | [Clase 1](clase1) | Expresión de la comunidad apostólica e iglesia |
# | [Clase 2](clase2) | Los perdidos, la oración y el plan del PE |
# | [Clase 3](clase3) | Los 4 elementos del evangelio - ILUMINE |
# | [Clase 4](clase4) | Nutrición (cap. 1 y 2) y taller de testimonio |
# | [Clase 5](clase5) | Evangelización |
# | [Tareas Adicionales](tareas_adicionales) | Evaluación de videos del testimonio |
#
# ---
#
# > Usa el panel de la izquierda para navegar entre clases.
